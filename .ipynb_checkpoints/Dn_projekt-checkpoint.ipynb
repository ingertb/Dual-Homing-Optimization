# %%
import  networkx as nx

# G = nx.Graph()
# er = nx.erdos_renyi_graph(100, 0.15)
# ws = nx.watts_strogatz_graph(30, 3, 0.1)
n_nodes=40
ba = nx.barabasi_albert_graph(n_nodes, 1)
# red = nx.random_lobster(20, 0.5, 0.9)
# print(nx.average_degree_connectivity(ba))
# print(nx.number_of_edges(ba))
# print(nx.degree(ba))

# %%
SRV_CMP_PWR = 1000
SRV_LINK_CAP = 100
RUT_LINK_CAP = 200

# Iterate over end nodes:
for v in nx.degree(ba):
    #if node connects only to one neighbour
    if v[1] == 1:

        #mark as endpoint:
        ba.nodes[v[0]]['type'] = 'Endpoint'
        #--print('node number: ', v[0], ba.nodes[v[0]]['type'])
        # print(ba.nodes[v[0]])

        #add maximum capacity of connection
        adj = list(nx.neighbors(ba, v[0]))
        # print(adj)
        ba[v[0]][adj[0]]['capacity'] = 100
        #--print(ba[v[0]][adj[0]])
    # elif 1<=v[1]<=4:
    #     print('aa')

        #if node has more connection choose whether is Server or router
    else:
        ba.nodes[v[0]]['type'] = 'Router' if v[0] % 2 == 0 else 'Server'
        # print('node number: ', v[0])
        # print(ba.nodes[v[0]])
        adj = list(nx.neighbors(ba, v[0]))
        for neig in adj:
            if ba.nodes[v[0]]['type'] == 'Router':
                ba[v[0]][neig]['capacity'] = RUT_LINK_CAP
                # print(node)
            if ba.nodes[v[0]]['type'] == 'Server':
                ba[v[0]][neig]['capacity'] = SRV_LINK_CAP
                # print(node)

    #--print('node number: ', v[0])
    # print(ba.nodes[v[0]])

# %%
import pandas as pd
#create dataframe
data = pd.DataFrame([], columns=['From_index','To_index','From_type','To_type','Cost','Capacity'])
for v in nx.degree(ba): 
    adj = list(nx.neighbors(ba, v[0]))
    for neig in adj:                      
        data = data.append(pd.DataFrame([[v[0]+1,neig+1,ba.nodes[v[0]]['type'],ba.nodes[neig]['type'],10,ba[v[0]][neig]['capacity']]], columns=['From_index','To_index','From_type','To_type','Cost','Capacity']), ignore_index = True) 
        #print(v[0],'-',neig,'|',ba.nodes[v[0]]['type'],'-',ba.nodes[neig]['type'],10,'|',ba[v[0]][neig]['capacity'])        
#add index route
data['route_id'] = data.index+1
data.to_csv('network.csv')

# %%
data.head(len(data))
# Out:
#    From_index To_index From_type   To_type Cost Capacity  route_id
# 0           1        2    Router    Server   10      100         1
# 1           1        3    Router  Endpoint   10      100         2
# 2           1        4    Router    Server   10      100         3
# 3           1        6    Router    Server   10      100         4
# 4           1        7    Router    Router   10      200         5
# 5           1        8    Router  Endpoint   10      100         6
# 6           1       10    Router  Endpoint   10      100         7
# 7           1       14    Router  Endpoint   10      100         8
# 8           1       16    Router    Server   10      100         9
# 9           1       20    Router  Endpoint   10      100        10
# 10          1       21    Router    Router   10      200        11
# 11          1       24    Router  Endpoint   10      100        12
# 12          1       28    Router  Endpoint   10      100        13
# 13          1       29    Router  Endpoint   10      100        14
# 14          1       34    Router  Endpoint   10      100        15
# 15          1       36    Router  Endpoint   10      100        16
# 16          1       37    Router  Endpoint   10      100        17
# 17          1       38    Router  Endpoint   10      100        18
# 18          1       40    Router  Endpoint   10      100        19
# 19          2        1    Server    Router   10      100        20
# 20          2        5    Server  Endpoint   10      100        21
# 21          2       35    Server    Router   10      200        22
# 22          3        1  Endpoint    Router   10      100        23
# 23          4        1    Server    Router   10      100        24
# 24          4       18    Server    Server   10      100        25
# 25          5        2  Endpoint    Server   10      100        26
# 26          6        1    Server    Router   10      100        27
# 27          6       13    Server  Endpoint   10      100        28
# 28          7        1    Router    Router   10      200        29
# 29          7        9    Router    Router   10      200        30
# ..        ...      ...       ...       ...  ...      ...       ...
# 48         16       30    Server  Endpoint   10      100        49
# 49         17       15  Endpoint    Router   10      100        50
# 50         18        4    Server    Server   10      100        51
# 51         18       26    Server    Server   10      100        52
# 52         19        7    Router    Router   10      200        53
# 53         19       32    Router  Endpoint   10      100        54
# 54         20        1  Endpoint    Router   10      100        55
# 55         21        1    Router    Router   10      200        56
# 56         21       22    Router  Endpoint   10      100        57
# 57         22       21  Endpoint    Router   10      100        58
# 58         23        7  Endpoint    Router   10      100        59
# 59         24        1  Endpoint    Router   10      100        60
# 60         25       15  Endpoint    Router   10      100        61
# 61         26       18    Server    Server   10      100        62
# 62         26       27    Server  Endpoint   10      100        63
# 63         27       26  Endpoint    Server   10      100        64
# 64         28        1  Endpoint    Router   10      100        65
# 65         29        1  Endpoint    Router   10      100        66
# 66         30       16  Endpoint    Server   10      100        67
# 67         31        7  Endpoint    Router   10      100        68
# 68         32       19  Endpoint    Router   10      100        69
# 69         33        7  Endpoint    Router   10      100        70
# 70         34        1  Endpoint    Router   10      100        71
# 71         35        2    Router    Server   10      200        72
# 72         35       39    Router  Endpoint   10      100        73
# 73         36        1  Endpoint    Router   10      100        74
# 74         37        1  Endpoint    Router   10      100        75
# 75         38        1  Endpoint    Router   10      100        76
# 76         39       35  Endpoint    Router   10      100        77
# 77         40        1  Endpoint    Router   10      100        78
#
# [78 rows x 7 columns]

# %%
Network = nx.Graph()
Network.add_nodes_from([1, n_nodes])
for i in range(len(data)):
    Network.add_edge(data['From_index'][i], data['To_index'][i])

# %%
import matplotlib.pyplot as plt
nx.draw(Network, with_labels=True, font_weight='bold')
plt.show()

# %%
Vn=n_nodes
En=0
for i in range(len(data)): 
    if En <= data['route_id'][i]:
        En = data['route_id'][i]

# %%
with open("data.dat", "w") as f:
    f.write("""
data;

param Vn := {Vn};
param En := {En};
param Dn := {Dn};

param : h  s  t :=
 1      {h} {s} {t}
;
        """.format(Vn=Vn, En=En, Dn=1, h=1, s=1, t=5))

# %%
with open("data.dat", "a") as f:
    f.write("""
param : A :=
""")

    for i in range(En):       
        f.write("""  {link_number}  {From_edge_number}    1
""".format(link_number=data['route_id'][i], From_edge_number=data['From_index'][i]))
    f.write(""";""")

# %%
with open("data.dat", "a") as f:
    f.write("""

param : B :=
""")
        
    for i in range(En):       
        f.write("""  {link_number}  {to_edge_number}    1
""".format(link_number=data['route_id'][i], to_edge_number=data['To_index'][i]))
    f.write(""";""")

# %%
with open("data.dat", "a") as f:
    f.write("""
     
param : K :=
""")
    for i in range(En):       
        f.write("""  {link_number}  {cost}
""".format(link_number=data['route_id'][i], cost=data['Cost'][i]))

# %%
with open("data.dat", "a") as f:
     f.write("""
;
end;
""")
